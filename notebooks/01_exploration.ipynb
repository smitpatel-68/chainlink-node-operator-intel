# %% [markdown]
# # Chainlink Node Operator Exploration
#
# Initial data exploration notebook.

# %%
import sys
sys.path.append('..')

from src.config import load_config

config = load_config()
config
